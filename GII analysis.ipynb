# %%
import numpy as np
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('GII.csv.csv',encoding='unicode_escape')

# %%
df.head()
# Out:
#    HDI rank                 Country HUMAN DEVELOPMENT GII VALUE GII RANK  \
# 0         1             Switzerland         VERY HIGH     0.018        3
# 1         2                  Norway         VERY HIGH     0.016        2
# 2         3                 Iceland         VERY HIGH     0.043        8
# 3         4  Hong Kong, China (SAR)         VERY HIGH        ..       ..
# 4         5               Australia         VERY HIGH     0.073       19
#
#   Maternal_mortality  Adolescent_birth_rate  \
# 0                  5                    2.2
# 1                  2                    2.3
# 2                  4                    5.4
# 3                 ..                    1.6
# 4                  6                    8.1
#
#   Seats_parliamentt(% held by women) F_secondary_educ M_secondary_educ  \
# 0                               39.8             96.9             97.5
# 1                                 45             99.1             99.3
# ...

# %%
df.shape
# Out:
# (195, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   HDI rank                            195 non-null    int64
#  1   Country                             195 non-null    object
#  2   HUMAN DEVELOPMENT                   195 non-null    object
#  3   GII VALUE                           195 non-null    object
#  4   GII RANK                            195 non-null    object
#  5   Maternal_mortality                  195 non-null    object
#  6   Adolescent_birth_rate               195 non-null    float64
#  7   Seats_parliamentt(% held by women)  195 non-null    object
#  8   F_secondary_educ                    195 non-null    object
#  9   M_secondary_educ                    195 non-null    object
#  10  F_Labour_force                      195 non-null    object
# ...

# %%
df=pd.read_csv('GII.csv.csv',na_values=['..'],encoding='unicode_escape')

# %%
df.head()
# Out:
#    HDI rank                 Country HUMAN DEVELOPMENT  GII VALUE  GII RANK  \
# 0         1             Switzerland         VERY HIGH      0.018       3.0
# 1         2                  Norway         VERY HIGH      0.016       2.0
# 2         3                 Iceland         VERY HIGH      0.043       8.0
# 3         4  Hong Kong, China (SAR)         VERY HIGH        NaN       NaN
# 4         5               Australia         VERY HIGH      0.073      19.0
#
#   Maternal_mortality  Adolescent_birth_rate  \
# 0                  5                    2.2
# 1                  2                    2.3
# 2                  4                    5.4
# 3                NaN                    1.6
# 4                  6                    8.1
#
#    Seats_parliamentt(% held by women)  F_secondary_educ  M_secondary_educ  \
# 0                                39.8              96.9              97.5
# 1                                45.0              99.1              99.3
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 195 entries, 0 to 194
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   HDI rank                            195 non-null    int64
#  1   Country                             195 non-null    object
#  2   HUMAN DEVELOPMENT                   195 non-null    object
#  3   GII VALUE                           170 non-null    float64
#  4   GII RANK                            170 non-null    float64
#  5   Maternal_mortality                  184 non-null    object
#  6   Adolescent_birth_rate               195 non-null    float64
#  7   Seats_parliamentt(% held by women)  193 non-null    float64
#  8   F_secondary_educ                    177 non-null    float64
#  9   M_secondary_educ                    177 non-null    float64
#  10  F_Labour_force                      180 non-null    float64
# ...

# %%
df.isna().sum()
# Out:
# HDI rank                               0
# Country                                0
# HUMAN DEVELOPMENT                      0
# GII VALUE                             25
# GII RANK                              25
# Maternal_mortality                    11
# Adolescent_birth_rate                  0
# Seats_parliamentt(% held by women)     2
# F_secondary_educ                      18
# M_secondary_educ                      18
# F_Labour_force                        15
# M_Labour_force                        15
# dtype: int64

# %%
df.dropna(inplace=True)

# %%
df.isna().sum()
# Out:
# HDI rank                              0
# Country                               0
# HUMAN DEVELOPMENT                     0
# GII VALUE                             0
# GII RANK                              0
# Maternal_mortality                    0
# Adolescent_birth_rate                 0
# Seats_parliamentt(% held by women)    0
# F_secondary_educ                      0
# M_secondary_educ                      0
# F_Labour_force                        0
# M_Labour_force                        0
# dtype: int64

# %%
df['GII VALUE'].fillna(df['GII VALUE'].mean(),inplace=True)
df['GII RANK'].fillna(df['GII RANK'].mean(),inplace=True)
df['F_secondary_educ'].fillna(df['F_secondary_educ'].mean(),inplace=True)

# %%
df.shape
# Out:
# (170, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 170 entries, 0 to 190
# Data columns (total 12 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   HDI rank                            170 non-null    int64
#  1   Country                             170 non-null    object
#  2   HUMAN DEVELOPMENT                   170 non-null    object
#  3   GII VALUE                           170 non-null    float64
#  4   GII RANK                            170 non-null    float64
#  5   Maternal_mortality                  170 non-null    object
#  6   Adolescent_birth_rate               170 non-null    float64
#  7   Seats_parliamentt(% held by women)  170 non-null    float64
#  8   F_secondary_educ                    170 non-null    float64
#  9   M_secondary_educ                    170 non-null    float64
#  10  F_Labour_force                      170 non-null    float64
# ...

# %%
df['Maternal_mortality' ]=df['Maternal_mortality'].astype('object')

# %% [markdown]
# # Expolatory Data Analysis

# %%
# Barchart for the count of human devlopment
HD_count=sns.countplot(x='HUMAN DEVELOPMENT',data=df)

# %%
sns.displot(df['Adolescent_birth_rate'] , kde=True)
df['Adolescent_birth_rate'].skew()
# Out:
# 1.0544309491727788

# %%
sns.displot(df['Seats_parliamentt(% held by women)'] , kde=True)
df['Seats_parliamentt(% held by women)'].skew()
# Out:
# 0.183731126981052

# %%
# converting country column to appropriate format 
country = coco.convert(names = df['Country'], to = "ISO3")
df['Country'] = country
residence = df['Country'].value_counts()
fig = px.choropleth(locations = residence.index,
                    color = residence.values,
                    color_continuous_scale=px.colors.sequential.YlGn,
                    title = 'Country Location')
fig.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4380\2986871201.py in <module>
#       1 # converting country column to appropriate format
# ----> 2 country = coco.convert(names = df['Country'], to = "ISO3")
#       3 df['Country'] = country
#       4 residence = df['Country'].value_counts()
#       5 fig = px.choropleth(locations = residence.index,
#
# NameError: name 'coco' is not defined

# %%
sns.jointplot(x='F_secondary_educ' , y = 'M_secondary_educ' , data=df , kind="reg")

# %%
sns.jointplot(x='M_Labour_force' , y='F_Labour_force' , data=df , kind="reg")

# %%
a=df.groupby('Country')['GII RANK'].sum().nsmallest(10).sort_values(ascending=True).plot(kind='bar')

# %%
sns.jointplot(x='GII RANK' , y = 'Seats_parliamentt(% held by women)' , data=df , kind="reg")

# %%
sns.jointplot(x='GII RANK' , y = 'HDI rank' , data=df , kind="reg")
